# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %% [markdown]
# ### Import the necessary libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %% [markdown]
# #### 1. Install TensorFlow Object Detection API
# - Please make sure you have installed tensorflow or tensorflow-gpu already.
# - For latest install instructions, check the [github](https://github.com/tensorflow/models/tree/master/research/object_detection) page or [readthedocs](https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/training.html) site for this API.

# %%
# !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 33643, done.
# remote: Total 33643 (delta 0), reused 0 (delta 0), pack-reused 33643
# Receiving objects: 100% (33643/33643), 511.93 MiB | 32.52 MiB/s, done.
# Resolving deltas: 100% (21535/21535), done.
# Checking out files: 100% (3194/3194), done.

# %%
#Verify that models folder exist
# !ls -l
# Out:
# total 8
# drwxr-xr-x 7 root root 4096 Jan 12 03:56 models
# drwxr-xr-x 1 root root 4096 Dec 18 16:52 sample_data

# %%
#Multiple folders including object_detection should exist in models/research folder
# !ls -l models/research/
# Out:
# total 280
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 a3c_blogpost
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 adversarial_crypto
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 adversarial_logit_pairing
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 adversarial_text
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 adv_imagenet_models
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 astronet
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 attention_ocr
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 audioset
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 autoaugment
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 autoencoder
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 brain_coder
# drwxr-xr-x 11 root root 4096 Jan 12 03:56 cognitive_mapping_and_planning
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 cognitive_planning
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 compression
# drwxr-xr-x  7 root root 4096 Jan 12 03:56 cvt_text
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 deep_contextual_bandits
# drwxr-xr-x  9 root root 4096 Jan 12 03:56 deeplab
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 deep_speech
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 delf
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 differential_privacy
# drwxr-xr-x  5 root root 4096 Jan 12 03:56 domain_adaptation
# drwxr-xr-x  8 root root 4096 Jan 12 03:56 efficient-hrl
# drwxr-xr-x  5 root root 4096 Jan 12 03:56 feelvos
# drwxr-xr-x  5 root root 4096 Jan 12 03:56 fivo
# drwxr-xr-x 12 root root 4096 Jan 12 03:56 gan
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 global_objectives
# drwxr-xr-x  5 root root 4096 Jan 12 03:56 im2txt
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 inception
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 keypointnet
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 learned_optimizer
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 learning_to_remember_rare_events
# drwxr-xr-x  5 root root 4096 Jan 12 03:56 learning_unsupervised_learning
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 lexnet_nc
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 lfads
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 lm_1b
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 lm_commonsense
# drwxr-xr-x 13 root root 4096 Jan 12 03:56 lstm_object_detection
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 marco
# drwxr-xr-x  8 root root 4096 Jan 12 03:56 maskgan
# drwxr-xr-x  7 root root 4096 Jan 12 03:56 morph_net
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 namignizer
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 neural_gpu
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 neural_programmer
# drwxr-xr-x  4 root root 4096 Jan 12 03:56 next_frame_prediction
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 nst_blogpost
# drwxr-xr-x 25 root root 4096 Jan 12 03:56 object_detection
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 pcl_rl
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 ptn
# drwxr-xr-x  5 root root 4096 Jan 12 03:56 qa_kg
# -rw-r--r--  1 root root 5008 Jan 12 03:56 README.md
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 real_nvp
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 rebar
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 resnet
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 sentiment_analysis
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 seq2species
# -rw-r--r--  1 root root  446 Jan 12 03:56 setup.py
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 skip_thoughts
# drwxr-xr-x  7 root root 4096 Jan 12 03:56 slim
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 steve
# drwxr-xr-x  6 root root 4096 Jan 12 03:56 street
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 struct2depth
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 swivel
# drwxr-xr-x 11 root root 4096 Jan 12 03:56 syntaxnet
# drwxr-xr-x  7 root root 4096 Jan 12 03:56 tcn
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 tensorrt
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 textsum
# drwxr-xr-x  3 root root 4096 Jan 12 03:56 transformer
# drwxr-xr-x  5 root root 4096 Jan 12 03:56 vid2depth
# drwxr-xr-x  2 root root 4096 Jan 12 03:56 video_prediction

# %%
#Install other dependencies including protobuf compiler
# !apt-get -qq install protobuf-compiler python-pil python-lxml python-tk
# !pip install --user Cython  --quiet
# !pip install --user contextlib2 --quiet
# !pip install --user jupyter --quiet
# !pip install --user matplotlib --quiet
# Out:
# Selecting previously unselected package python-bs4.
# (Reading database ... 135004 files and directories currently installed.)
# Preparing to unpack .../0-python-bs4_4.6.0-1_all.deb ...
# Unpacking python-bs4 (4.6.0-1) ...
# Selecting previously unselected package python-pkg-resources.
# Preparing to unpack .../1-python-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python-chardet.
# Preparing to unpack .../2-python-chardet_3.0.4-1_all.deb ...
# Unpacking python-chardet (3.0.4-1) ...
# Selecting previously unselected package python-six.
# Preparing to unpack .../3-python-six_1.11.0-2_all.deb ...
# Unpacking python-six (1.11.0-2) ...
# Selecting previously unselected package python-webencodings.
# Preparing to unpack .../4-python-webencodings_0.5-2_all.deb ...
# Unpacking python-webencodings (0.5-2) ...
# Selecting previously unselected package python-html5lib.
# Preparing to unpack .../5-python-html5lib_0.999999999-1_all.deb ...
# Unpacking python-html5lib (0.999999999-1) ...
# Selecting previously unselected package python-lxml:amd64.
# Preparing to unpack .../6-python-lxml_4.2.1-1ubuntu0.1_amd64.deb ...
# Unpacking python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Selecting previously unselected package python-olefile.
# Preparing to unpack .../7-python-olefile_0.45.1-1_all.deb ...
# Unpacking python-olefile (0.45.1-1) ...
# Selecting previously unselected package python-pil:amd64.
# Preparing to unpack .../8-python-pil_5.1.0-1_amd64.deb ...
# Unpacking python-pil:amd64 (5.1.0-1) ...
# Setting up python-pkg-resources (39.0.1-2) ...
# Setting up python-six (1.11.0-2) ...
# Setting up python-bs4 (4.6.0-1) ...
# Setting up python-lxml:amd64 (4.2.1-1ubuntu0.1) ...
# Setting up python-olefile (0.45.1-1) ...
# Setting up python-pil:amd64 (5.1.0-1) ...
# Setting up python-webencodings (0.5-2) ...
# Setting up python-chardet (3.0.4-1) ...
# Setting up python-html5lib (0.999999999-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# Protobuf compilation
# - Convert .pb files to python code in object detection folder

# %%
#Move to models/research folder
# %cd models/research

#Convert protobuf files to Python code using Protobuf compiler installed in previous step
# !protoc object_detection/protos/*.proto --python_out=.
# !ls -l object_detection/protos
# Out:
# /content/models/research
# total 724
# -rw-r--r-- 1 root root   6848 Jan 12 04:01 anchor_generator_pb2.py
# -rw-r--r-- 1 root root    747 Jan 12 03:56 anchor_generator.proto
# -rw-r--r-- 1 root root   4359 Jan 12 04:01 argmax_matcher_pb2.py
# -rw-r--r-- 1 root root   1151 Jan 12 03:56 argmax_matcher.proto
# -rw-r--r-- 1 root root   2175 Jan 12 04:01 bipartite_matcher_pb2.py
# -rw-r--r-- 1 root root    350 Jan 12 03:56 bipartite_matcher.proto
# -rw-r--r-- 1 root root   6208 Jan 12 04:01 box_coder_pb2.py
# -rw-r--r-- 1 root root    656 Jan 12 03:56 box_coder.proto
# -rw-r--r-- 1 root root  35788 Jan 12 04:01 box_predictor_pb2.py
# -rw-r--r-- 1 root root   7366 Jan 12 03:56 box_predictor.proto
# -rw-r--r-- 1 root root  24908 Jan 12 04:01 calibration_pb2.py
# -rw-r--r-- 1 root root   2876 Jan 12 03:56 calibration.proto
# -rw-r--r-- 1 root root  13553 Jan 12 04:01 eval_pb2.py
# -rw-r--r-- 1 root root   3923 Jan 12 03:56 eval.proto
# -rw-r--r-- 1 root root   3445 Jan 12 04:01 faster_rcnn_box_coder_pb2.py
# -rw-r--r-- 1 root root    531 Jan 12 03:56 faster_rcnn_box_coder.proto
# -rw-r--r-- 1 root root  24448 Jan 12 04:01 faster_rcnn_pb2.py
# -rw-r--r-- 1 root root   8484 Jan 12 03:56 faster_rcnn.proto
# -rw-r--r-- 1 root root   6105 Jan 12 04:01 flexible_grid_anchor_generator_pb2.py
# -rw-r--r-- 1 root root    816 Jan 12 03:56 flexible_grid_anchor_generator.proto
# -rw-r--r-- 1 root root   4720 Jan 12 04:01 graph_rewriter_pb2.py
# -rw-r--r-- 1 root root    847 Jan 12 03:56 graph_rewriter.proto
# -rw-r--r-- 1 root root   5082 Jan 12 04:01 grid_anchor_generator_pb2.py
# -rw-r--r-- 1 root root   1020 Jan 12 03:56 grid_anchor_generator.proto
# -rw-r--r-- 1 root root  26158 Jan 12 04:01 hyperparams_pb2.py
# -rw-r--r-- 1 root root   4061 Jan 12 03:56 hyperparams.proto
# -rw-r--r-- 1 root root  17448 Jan 12 04:01 image_resizer_pb2.py
# -rw-r--r-- 1 root root   3445 Jan 12 03:56 image_resizer.proto
# -rw-r--r-- 1 root root      0 Jan 12 03:56 __init__.py
# -rw-r--r-- 1 root root  17379 Jan 12 04:01 input_reader_pb2.py
# -rw-r--r-- 1 root root   5132 Jan 12 03:56 input_reader.proto
# -rw-r--r-- 1 root root   3810 Jan 12 04:01 keypoint_box_coder_pb2.py
# -rw-r--r-- 1 root root    575 Jan 12 03:56 keypoint_box_coder.proto
# -rw-r--r-- 1 root root  38048 Jan 12 04:01 losses_pb2.py
# -rw-r--r-- 1 root root   7552 Jan 12 03:56 losses.proto
# -rw-r--r-- 1 root root   3882 Jan 12 04:01 matcher_pb2.py
# -rw-r--r-- 1 root root    418 Jan 12 03:56 matcher.proto
# -rw-r--r-- 1 root root   2184 Jan 12 04:01 mean_stddev_box_coder_pb2.py
# -rw-r--r-- 1 root root    293 Jan 12 03:56 mean_stddev_box_coder.proto
# -rw-r--r-- 1 root root   5805 Jan 12 04:01 model_pb2.py
# -rw-r--r-- 1 root root    667 Jan 12 03:56 model.proto
# -rw-r--r-- 1 root root   4438 Jan 12 04:01 multiscale_anchor_generator_pb2.py
# -rw-r--r-- 1 root root    847 Jan 12 03:56 multiscale_anchor_generator.proto
# -rw-r--r-- 1 root root  28035 Jan 12 04:01 optimizer_pb2.py
# -rw-r--r-- 1 root root   3327 Jan 12 03:56 optimizer.proto
# -rw-r--r-- 1 root root   6430 Jan 12 04:01 pipeline_pb2.py
# -rw-r--r-- 1 root root    773 Jan 12 03:56 pipeline.proto
# -rw-r--r-- 1 root root  10448 Jan 12 04:01 post_processing_pb2.py
# -rw-r--r-- 1 root root   2905 Jan 12 03:56 post_processing.proto
# -rw-r--r-- 1 root root 121055 Jan 12 04:01 preprocessor_pb2.py
# -rw-r--r-- 1 root root  19720 Jan 12 03:56 preprocessor.proto
# -rw-r--r-- 1 root root   9582 Jan 12 04:01 region_similarity_calculator_pb2.py
# -rw-r--r-- 1 root root    950 Jan 12 03:56 region_similarity_calculator.proto
# -rw-r--r-- 1 root root   2944 Jan 12 04:01 square_box_coder_pb2.py
# -rw-r--r-- 1 root root    419 Jan 12 03:56 square_box_coder.proto
# -rw-r--r-- 1 root root   7278 Jan 12 04:01 ssd_anchor_generator_pb2.py
# -rw-r--r-- 1 root root   2254 Jan 12 03:56 ssd_anchor_generator.proto
# -rw-r--r-- 1 root root  27896 Jan 12 04:01 ssd_pb2.py
# -rw-r--r-- 1 root root   9376 Jan 12 03:56 ssd.proto
# -rw-r--r-- 1 root root   4387 Jan 12 04:01 string_int_label_map_pb2.py
# -rw-r--r-- 1 root root    724 Jan 12 03:56 string_int_label_map.proto
# -rw-r--r-- 1 root root   4176 Jan 12 04:01 target_assigner_pb2.py
# -rw-r--r-- 1 root root    443 Jan 12 03:56 target_assigner.proto
# -rw-r--r-- 1 root root  15802 Jan 12 04:01 train_pb2.py
# -rw-r--r-- 1 root root   5378 Jan 12 03:56 train.proto

# %%
#Setup environment variable
#Change path to models/research and models/research/slim folders based on where you have cloned github repository above
# %set_env PYTHONPATH=$PYTHONPATH:/content/models/research:/content/models/research/slim
# Out:
# env: PYTHONPATH=$PYTHONPATH:/content/models/research:/content/models/research/slim

# %%
#To be run from models/research folder
# !python object_detection/builders/model_builder_test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTest.test_create_experimental_model
# [       OK ] ModelBuilderTest.test_create_experimental_model
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [       OK ] ModelBuilderTest.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTest.test_create_rfcn_model_from_config
# [       OK ] ModelBuilderTest.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_fpn_model_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTest.test_create_ssd_models_from_config
# [       OK ] ModelBuilderTest.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTest.test_invalid_faster_rcnn_batchnorm_update
# [       OK ] ModelBuilderTest.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTest.test_invalid_first_stage_nms_iou_threshold
# [       OK ] ModelBuilderTest.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTest.test_invalid_model_config_proto
# [       OK ] ModelBuilderTest.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTest.test_invalid_second_stage_batch_size
# [       OK ] ModelBuilderTest.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTest.test_session
# [  SKIPPED ] ModelBuilderTest.test_session
# [ RUN      ] ModelBuilderTest.test_unknown_faster_rcnn_feature_extractor
# [       OK ] ModelBuilderTest.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTest.test_unknown_meta_architecture
# [       OK ] ModelBuilderTest.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTest.test_unknown_ssd_feature_extractor
# [       OK ] ModelBuilderTest.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 17 tests in 0.218s
#
# OK (skipped=1)

# %% [markdown]
# ### Change directory

# %%
import os
os.chdir('/content/drive/My Drive/AIML/Computer Vision/AdvCompVis/Lab_internal/')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Load the training data from train.csv file

# %%
train_data=pd.read_csv('/content/drive/My Drive/AIML/Computer Vision/AdvCompVis/Lab_internal/train_labels.csv')

# %%
train_data.head()
# Out:
#          filename  width  height    class  xmin  ymin  xmax  ymax
# 0  raccoon-17.jpg    259     194  raccoon    95    60   167   118
# 1  raccoon-11.jpg    660     432  raccoon     3     1   461   431
# 2  raccoon-63.jpg    600     400  raccoon    74   107   280   290
# 3  raccoon-63.jpg    600     400  raccoon   227    93   403   298
# 4  raccoon-60.jpg    273     185  raccoon    58    33   197   127

# %%
len(train_data['class'].unique())
# Out:
# 1

# %% [markdown]
# ### Print the shape of the train dataset

# %%
train_data.shape
# Out:
# (173, 8)

# %%
# !pip install patool
import patoolib
patoolib.extract_archive('images_racoon-1.rar')
# Out:
# Requirement already satisfied: patool in /usr/local/lib/python3.6/dist-packages (1.12)
# patool: Extracting images_racoon-1.rar ...
# patool: running /usr/bin/unrar x -- "/content/drive/My Drive/AIML/Computer Vision/AdvCompVis/Lab_internal/images_racoon-1.rar"
# patool:     with cwd='./Unpack_f66r6ntd'
# patool: ... images_racoon-1.rar extracted to `images'.
# 'images'

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
IMAGE_SIZE=128

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
import csv
with open('train_labels.csv','r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile) - 1, 4))
    spamreader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    next(spamreader, None)
    for i,row in enumerate(spamreader):
        #print(row)
        for j, r in enumerate(row): # Parse row with seven entities
            #print(i)
            if((j!= 0) & (j!=3)):
                row[j] = int(r)
            
        #print(row)      
        path, width, height, class_, xmin, ymin, xmax, ymax = row
        paths.append(path)
        #print(i)
        coords[i,0] = xmin * IMAGE_SIZE / width
        coords[i,1] = ymin * IMAGE_SIZE / height
        coords[i,2] = xmax * IMAGE_SIZE / width # Normalize bounding box by image size
        coords[i,3] = ymax * IMAGE_SIZE / height

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
#Find all rows which have same file name
batch_images = np.zeros(shape=(len(paths),IMAGE_SIZE,IMAGE_SIZE,3),dtype=np.float32)

# %%
from PIL import Image
from keras_applications import mobilenet
from keras.applications.mobilenet import preprocess_input
from keras.backend import epsilon
from keras.models import Model
from keras.layers import Conv2D
from keras.layers import Reshape

# %%
for i,img_name in enumerate(paths):
  img=Image.open('/content/drive/My Drive/AIML/Computer Vision/AdvCompVis/Lab_internal/images/'+img_name)
  img=img.resize((IMAGE_SIZE,IMAGE_SIZE))
  img = img.convert("RGB")
  batch_images[i]=preprocess_input(np.array(img,dtype=np.float32))

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
from keras.applications.mobilenet import MobileNet
IMG_SHAPE=(IMAGE_SIZE, IMAGE_SIZE, 3)
model = MobileNet(input_shape=IMG_SHAPE,include_top=False,alpha=1.0)

# %%
for layers in model.layers:
  layers.trainable=False

# %%
X=model.layers[-1].output
X=Conv2D(4,kernel_size=4)(X)
X=Reshape((4,))(X)

# %%
model=Model(inputs=model.input, output=X)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("re...)`
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_func(loss, [y_true, y_pred], tf.float32)
    return iou

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
import tensorflow as tf
model.compile(optimizer='adam',loss='mse',metrics=[IoU])
# Out:
# WARNING:tensorflow:From <ipython-input-115-a811784d62ce>:25: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.

# %%
model.fit(batch_images,coords,epochs=30,batch_size=32,verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/30
# 173/173 [==============================] - 6s 36ms/step - loss: 4125.3750 - IoU: 0.0734
# Epoch 2/30
# 173/173 [==============================] - 5s 26ms/step - loss: 835.7167 - IoU: 0.3899
# Epoch 3/30
# 173/173 [==============================] - 5s 27ms/step - loss: 429.4587 - IoU: 0.5856
# Epoch 4/30
# 173/173 [==============================] - 4s 26ms/step - loss: 621.8657 - IoU: 0.5201
# Epoch 5/30
# 173/173 [==============================] - 5s 26ms/step - loss: 414.8423 - IoU: 0.5760
# Epoch 6/30
# 173/173 [==============================] - 5s 27ms/step - loss: 230.6889 - IoU: 0.6354
# Epoch 7/30
# 173/173 [==============================] - 5s 27ms/step - loss: 211.2336 - IoU: 0.6361
# Epoch 8/30
# 173/173 [==============================] - 5s 27ms/step - loss: 193.7846 - IoU: 0.6674
# Epoch 9/30
# 173/173 [==============================] - 5s 26ms/step - loss: 159.3850 - IoU: 0.7032
# Epoch 10/30
# 173/173 [==============================] - 5s 26ms/step - loss: 135.9216 - IoU: 0.7359
# Epoch 11/30
# 173/173 [==============================] - 5s 27ms/step - loss: 115.2802 - IoU: 0.7604
# Epoch 12/30
# 173/173 [==============================] - 5s 27ms/step - loss: 105.0281 - IoU: 0.7604
# Epoch 13/30
# 173/173 [==============================] - 5s 27ms/step - loss: 101.1368 - IoU: 0.7645
# Epoch 14/30
# 173/173 [==============================] - 5s 27ms/step - loss: 94.0817 - IoU: 0.7721
# Epoch 15/30
# 173/173 [==============================] - 5s 27ms/step - loss: 92.9626 - IoU: 0.7728
# Epoch 16/30
# 173/173 [==============================] - 5s 28ms/step - loss: 86.1848 - IoU: 0.7849
# Epoch 17/30
# 173/173 [==============================] - 5s 27ms/step - loss: 80.3984 - IoU: 0.7889
# Epoch 18/30
# 173/173 [==============================] - 5s 27ms/step - loss: 78.5791 - IoU: 0.7902
# Epoch 19/30
# 173/173 [==============================] - 5s 26ms/step - loss: 81.4241 - IoU: 0.7872
# Epoch 20/30
# 173/173 [==============================] - 5s 26ms/step - loss: 73.6202 - IoU: 0.7972
# Epoch 21/30
# 173/173 [==============================] - 5s 26ms/step - loss: 73.5098 - IoU: 0.8063
# Epoch 22/30
# 173/173 [==============================] - 5s 26ms/step - loss: 66.1677 - IoU: 0.8155
# Epoch 23/30
# 173/173 [==============================] - 5s 26ms/step - loss: 67.8722 - IoU: 0.8108
# Epoch 24/30
# 173/173 [==============================] - 5s 26ms/step - loss: 65.9267 - IoU: 0.8091
# Epoch 25/30
# 173/173 [==============================] - 5s 27ms/step - loss: 67.7483 - IoU: 0.8050
# Epoch 26/30
# 173/173 [==============================] - 5s 26ms/step - loss: 64.4945 - IoU: 0.8031
# Epoch 27/30
# 173/173 [==============================] - 5s 27ms/step - loss: 68.9749 - IoU: 0.8046
# Epoch 28/30
# 173/173 [==============================] - 5s 27ms/step - loss: 63.2572 - IoU: 0.8143
# Epoch 29/30
# 173/173 [==============================] - 5s 29ms/step - loss: 61.0345 - IoU: 0.8212
# Epoch 30/30
# 173/173 [==============================] - 5s 27ms/step - loss: 62.8526 - IoU: 0.8226

# %% [markdown]
# ### Pick a test image from the given data

# %%
img = cv2.imread('/images/' + img_file)

# %%
# Pick a test image, run model, show image, and show predicted bounding box overlaid on the image
import cv2

#Pickup a random image number
img_num = np.random.randint(0, train_data.shape[0])

#Read the image
img_file = '/content/drive/My Drive/AIML/Computer Vision/AdvCompVis/Lab_internal/images/' +paths[img_num]

#image_name = 'images/raccoon-144.jpg'
unscaled = cv2.imread(img_file) # Original image for display
image_height, image_width, _ = unscaled.shape
print(image_height,image_width,)
# Out:
# 360 640

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE)) # Rescaled image to run the network
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = model.predict(x=np.array([feat_scaled]))[0] # Predict the BBox

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * image_width / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * image_height / IMAGE_SIZE)

x1 = int((region[2]) * image_width / IMAGE_SIZE)
y1 = int((region[3]) * image_height / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0) , (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()
