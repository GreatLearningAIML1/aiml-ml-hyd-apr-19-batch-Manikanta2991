# %% [markdown]
# ## Lab 2

# %% [markdown]
# Welcome to the second lab of the AIML!
# In addition to implementing code, there will be questions that you must answer which relate to the lab and your implementation. Each question you will answer is preceded by a **'Question X'** header. Carefully read each question and provide you answer or code in the following textboxes with **'Answer:'** header. Your lab submission will be evaluated based on your answers to each of the questions and the implementation you provide.

# %% [markdown]
# # Every question is of 1 mark.

# %% [markdown]
# ## Overview

# %% [markdown]
# This module covers,
#
# 1) One sample and Two sample t-tests
#
# 2) ANOVA
#
# 3) Type I and Type II errors
#
# 4) Probabilty Distributions
#
# 5) Linear Regression

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# The purpose of the test is to tell if there is any significant difference between two data sets.

# %% [markdown]
# ## Question 1
#
# *A student is trying to decide between two GPUs. He want to use the GPU for his research to run Deep learning algorithms, so the only thing he is concerned with is speed.*
#
# *He picks a Deep Learning algorithm on a large data set and runs it on both GPUs 15 times, timing each run in hours. Results are given in the below lists GPU1 and GPU2.*

# %% [markdown]
# Hint: You can import ttest function from scipy to perform t tests

# %% [markdown]
# Given,
#
# Null Hypothesis : There is no significant difference between data sets
#
# Alternate Hypothesis : There is a significant difference
#
# *Do two-sample testing and check whether to reject Null Hypothesis or not.*
#
# #### Answer:

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as mt
from scipy.stats import ttest_ind, levene, f_oneway
from statsmodels.stats.anova import anova_lm
from sklearn.model_selection import train_test_split

# %%
GPU1 = pd.DataFrame([11,9,10,11,10,12,9,11,12,9,11,12,9,10,9])
GPU2 = pd.DataFrame([11,13,10,13,12,9,11,12,12,11,12,12,10,11,13])
t_statistic, p_value = ttest_ind(GPU1, GPU2)
print('Since the "P"',p_value,'value is less than 0.05 against 95% confidence interval, null hypothesis is rejected, \n thus there is a significant difference exists')
# Out:
# Since the "P" [0.01379428] value is less than 0.05 against 95% confidence interval, null hypothesis is rejected,
#  thus there is a significant difference exists

# %% [markdown]
# [## Question 2
# ](https://)
# He is trying a third GPU which is GPU3.

# %%
GPU3 = pd.DataFrame([9,10,9,11,10,13,12,9,12,12,13,12,13,10,11])

#Assumption: Both the datasets (GPU1 & GPU 3) are random, independent, parametric & normally distributed

# %% [markdown]
# *Do two-sample testing and check whether there is significant differene between speeds of two GPUs GPU1 and GPU3.*
#
# #### Answer:

# %%
t_statistic, p_value = ttest_ind(GPU1, GPU3)
print('Since the "P"',p_value,'value is greater than 0.05 against 95% confidence interval, null hypothesis is not rejected, \n Hince there is no-significant difference exists')
# Out:
# Since the "P" [0.14509211] value is greater than 0.05 against 95% confidence interval, null hypothesis is not rejected,
#  Hince there is no-significant difference exists

# %% [markdown]
# ### ANOVA

# %% [markdown]
# ## Question 3
#
# If you need to compare more than two data sets at a time, an ANOVA is your best bet.
#
# *The results from three experiments with overlapping 95% confidence intervals are given below, and we want to confirm that the results for all three experiments are not significantly different.*
#
# #Assumption: All the 3 datasets (e1,e2 & e3) are random, independent, parametric & normally distributed
# But before conducting ANOVA, test equality of variances (using Levene's test) is satisfied or not. If not, then mention that we cannot depend on the result of ANOVA

# %%
import pandas as pd
e1 = pd.DataFrame([1.595440,1.419730,0.000000,0.000000])
e2 = pd.DataFrame([1.433800,2.079700,0.892139,2.384740])
e3 = pd.DataFrame([0.036930,0.938018,0.995956,1.006970])

# %% [markdown]
# Hint - You can use stats.levene function and stats.f_oneway function.

# %% [markdown]
# #### Answer:

# %%
print(stats.levene(e1[0].values,e2[0].values,e3[0].values))
f, p = f_oneway(e1[0].values,e2[0].values,e3[0].values)
print ('F value:', f)
print ('P value:', p, '\n')
print('Since P-Value is greater than .05 against 95% confidance interval, Thus Test equality of variances (using Levene test) is satisfied')
# Out:
# LeveneResult(statistic=2.6741725711150446, pvalue=0.12259792666001798)
# F value: 2.51357622845924
# P value: 0.13574644501798466
#
# Since P-Value is greater than .05 against 95% confidance interval, Thus Test equality of variances (using Levene test) is satisfied

# %% [markdown]
# ## Question 4
#
# *In one or two sentences explain about **TypeI** and **TypeII** errors.*
#
# #### Answer:

# %%
print('Type I error: This is the rejection of a true null hypothesis, which could impact significantly in case of email spam for official purpose')
# Out:
# Type I error: This is the rejection of a true null hypothesis, which could impact significantly in case of email spam for official purpose

# %%
print('Typer II error:  This is the failure to reject null hypothesis, which could impact significantly in case of Medical equipement fields')
# Out:
# Typer II error:  This is the failure to reject null hypothesis, which could impact significantly in case of Medical equipement fields

# %% [markdown]
# # Question 5
# You are a manager of a chinese restaurant. You want to determine whether the waiting time to place an order has changed in the past month from its previous population mean value of 4.5 minutes.
# State the null and alternative hypothesis.

# %%
print('Null Hypothesis : Mean = 4.5')
# Out:
# Null Hypothesis : Mean = 4.5

# %%
print('Alternate Hypothesis : Mean != 4.5')
# Out:
# Alternate Hypothesis : Mean != 4.5

# %%
print('If i can prove that the Mean is not equal to 4.5, then the Null Hypothesis gets rejected and the change in waiting time can be proved.')
# Out:
# If i can prove that the Mean is not equal to 4.5, then the Null Hypothesis gets rejected and the change in waiting time can be proved.

# %% [markdown]
# # Question 6
# Get the binomial distribution with n = 10, p = .7 and k = [0, 1, 2, 3, 4, 5, 6, 7]
#
# Hint - Use stats.binom.pmf() function for this.

# %%
n = 10, 
p = .7
k = [0, 1, 2, 3, 4, 5, 6, 7]
distr = stats.binom.pmf(k,10,.7)
print('Below lists the probability for different values in "K" dataset using binomial distribution\n', distr)
# Out:
# Below lists the probability for different values in "K" dataset using binomial distribution
#  [5.90490000e-06 1.37781000e-04 1.44670050e-03 9.00169200e-03
#  3.67569090e-02 1.02919345e-01 2.00120949e-01 2.66827932e-01]

# %% [markdown]
# # Question 7
# Plot the distribution created in the above question.

# %%
print('Below shows the distribution')
mt.plot(k,distr)
mt.title('Binomial distribution: P=%.2F' %(p), fontsize=12)
mt.xlabel('Number of success/failure')
mt.ylabel('Probability of success/failure')
# Out:
# Below shows the distribution
# Text(0, 0.5, 'Probability of success/failure')

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Here we will try to see that if we can make a regression model to predict one column of a dataset by the use of other coloumn.
#
# ## Dataset
#
# Population of U.S. Cities
#
# ### Description
# The bigcity data frame has 49 rows and 2 columns.
#
# The measurements are the population (in 1000's) of 49 U.S. cities in 1920 and 1930. The 49 cities are a random sample taken from the 196 largest cities in 1920.
#
# ### Format
# This data frame contains the following columns:
#
# `u`
# The 1920 population.
#
# `x`
# The 1930 population.
#
# There is one unnamed column also in this dataset. Please remove and ignore that coloumn.
#
# Source
#
# The data were obtained from
#
# Cochran, W.G. (1977) Sampling Techniques. Third edition. John Wiley
#
# References
#
# Davison, A.C. and Hinkley, D.V. (1997) Bootstrap Methods and Their Application. Cambridge University Press.

# %% [markdown]
# # Question 8
# Read the dataset given in file named 'bigcity.csv'.

# %%
Dataset=pd.read_csv('bigcity.csv')
Dataset.head()
# Out:
#    Unnamed: 0    u    x
# 0           1  138  143
# 1           2   93  104
# 2           3   61   69
# 3           4  179  260
# 4           5   48   75

# %% [markdown]
# # Question 9 - Transform the dataset
# Find the number of rows in given dataset and separate the input(u column)  and target variables(x column) into X and Y.
#
# Remove the unnamed coloumn.
#
# Hint: You can shape function to get the size of the dataframe

# %%
print('Shape of the dataset is:',Dataset.shape,',we can see that there are 49 rows')
Dataset.drop(Dataset.columns[0], axis=1, inplace=True)
print('Also, unnamed column is removed')
X = Dataset[['u']]
Y = Dataset[['x']]
print('The dataset is separated into input "X" (u column) and target variable "Y" (x column)')
# Out:
# Shape of the dataset is: (49, 3) ,we can see that there are 49 rows
# Also, unnamed column is removed
# The dataset is separated into input "X" (u column) and target variable "Y" (x column)

# %% [markdown]
# ## Question 10 - Check the dataset for any missing values and also print out the correlation matrix

# %%
print('Is thre is any mising/null value in the dataset is:' ,Dataset.isnull().values.any(),', thus we can say that there are no missing values in the dataset')
# Out:
# Is thre is any mising/null value in the dataset is: False , thus we can say that there are no missing values in the dataset

# %% [markdown]
# You can use .isna() and .corr() functions to check NA's and correlation in the dataframe respectively

# %%
print('Is thre is any mising/null value in the dataset is:' ,Dataset.isna().values.any(),', thus we can say that there are no missing values in the dataset')
# Out:
# Is thre is any mising/null value in the dataset is: False , thus we can say that there are no missing values in the dataset

# %%
print('Correlation for the the two columns are listed below')
Dataset.corr()
# Out:
# Correlation for the the two columns are listed below
#           u         x
# u  1.000000  0.981742
# x  0.981742  1.000000

# %% [markdown]
# ### The high correlation betwwen u and x indicates that the variable u is a good predictor of variable x

# %% [markdown]
# # Question 11 - Split data into train, test sets
# Divide the data into training and test sets with 80-20 split using scikit-learn. Print the shapes of training and test feature sets.*

# %% [markdown]
# Check: train_test_split function

# %%
X_train, X_test, Y_train, Y_test =train_test_split(X,Y,test_size=0.2,train_size=0.8,random_state=101)
print('Data is now divided into 80% train data (X_train, Y_train) and 20% test data (X_test, Y_test)')
# Out:
# Data is now divided into 80% train data (X_train, Y_train) and 20% test data (X_test, Y_test)

# %% [markdown]
# # Question 12 - Find coefficients & intercept
# Estimate the coefficients b0 and b1 using scikit-learn.

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# Check: coef_ and intercept_ functions can help you get coefficients & intercept

# %%
m = regr.coef_
c = regr.intercept_
print('The coefficient is',regr.coef_,'and intercept is',regr.intercept_)
# Out:
# The coefficient is [[1.08072871]] and intercept is [16.03609996]

# %% [markdown]
# # Question 13 - Linear Relationship between feature and target
# Plot the line with b1 and b0 as slope and y-intercept.
#
# Hint - y = mx + c, plot y

# %%
y_predic=m*X_train + c
mt.scatter(X_train,Y_train)
mt.plot(X_train,y_predic)
mt.xlabel('Input "X_train"(u column)', fontsize=10)
mt.ylabel('Target variable "Y_train"(x column)', fontsize=10)
# Out:
# Text(0, 0.5, 'Target variable "Y_train"(x column)')

# %% [markdown]
# # Question 14 - Evaluation of model with scikit-learn
# Validate the model with Root Mean Squares error and R^2 score using scikit-learn. RMSE and R2 for test data and prediction

# %% [markdown]
# Hint: You can import mean_squared_error function & r2 (R square) from sklearn.metrics. Performing root operation over mean square error over mean square error gives you root mean square error

# %%
y_pred = regr.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
mse = mean_squared_error(Y_test, y_pred)
print('mean_squared_error is:',mse)
rmse = sqrt(mse)
print('r2 (R square) is:',rmse)
# Out:
# mean_squared_error is: 842.4471230487685
# r2 (R square) is: 29.024939673473373

# %% [markdown]
# ## Question 15 - Calculate the accuracy of the model for both training and test data set

# %% [markdown]
# ### Hint: .score() function

# %%
print('Accuracy of the model for both training data set:',regr.score(X_train,Y_train))
print('Accuracy of the model for test data set:',regr.score(X_test,Y_test))
# Out:
# Accuracy of the model for both training data set: 0.9362637328012845
# Accuracy of the model for test data set: 0.9773519951241559
